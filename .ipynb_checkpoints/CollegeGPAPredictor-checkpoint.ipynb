# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./sat_gpa_v1.csv')
df
# Out:
#      sat_sum  fy_gpa
# 0       1270    3.18
# 1       1220    3.33
# 2       1160    3.25
# 3        950    2.42
# 4       1070    2.63
# ..       ...     ...
# 995     1000    2.19
# 996     1080    1.50
# 997     1140    3.17
# 998     1200    1.94
# 999      930    2.38
#
# [1000 rows x 2 columns]

# %%
print('the number of null values in data is ', df.isna().sum())
print('the number of duplicated values in data is ', df.duplicated().sum())

#given the limited number of varibles I believe it is highly likely that the 49 duplicates 
# can happen naturally in the dataset and are true values. Meaning they should not be dropped out of the data used.
# Out:
# the number of null values in data is  sat_sum    0
# fy_gpa     0
# dtype: int64
# the number of duplicated values in data is  49

# %%
#plotting the scatter plot of GPA and SAT score
plt.figure(figsize=(10, 6))
plt.scatter(y= 'fy_gpa', x='sat_sum', data=df)
plt.title('Relationship between GPA and SAT Scores')
plt.ylabel('GPA')
plt.xlabel('SAT Scores')

plt.show()

# %%
import statsmodels.api as sm

# %%
x = df['sat_sum']
y = df['fy_gpa']
x = sm.add_constant(x)

# Fit the regression model
model = sm.OLS(y, x).fit()
model

# %%
# Plot the data points and the regression line
plt.scatter(x='sat_sum',y= 'fy_gpa', data=df, marker='o', linestyle='-', alpha=0.2)
plt.plot(x, model.predict(x))
plt.xlabel('SAT Summary (Math + Verbal)')
plt.ylabel('GPA')
plt.title('Correlation between GPA vs. SAT Scores')
plt.show()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 fy_gpa   R-squared:                       0.212
# Model:                            OLS   Adj. R-squared:                  0.211
# Method:                 Least Squares   F-statistic:                     268.3
# Date:                Mon, 03 Jun 2024   Prob (F-statistic):           1.39e-53
# Time:                        15:53:05   Log-Likelihood:                -999.38
# No. Observations:                1000   AIC:                             2003.
# Df Residuals:                     998   BIC:                             2013.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0019      0.152      0.013      0.990      -0.296       0.300
# ...

# %% [markdown]
# My analysis of the correlation of Sat Score to GPA is that there is a fairly strong positive one. I know that the scales of the 2 variable are very different with SAT scores ranging from ~450 to 1400 and GPA being from 0-4.0 but the higher the SAT score generally the higher the first year GPA.

# %%
print(x['sat_sum'])
y
# Out:
# 0      1270
# 1      1220
# 2      1160
# 3       950
# 4      1070
#        ...
# 995    1000
# 996    1080
# 997    1140
# 998    1200
# 999     930
# Name: sat_sum, Length: 1000, dtype: int64
# 0      3.18
# 1      3.33
# 2      3.25
# 3      2.42
# 4      2.63
#        ...
# 995    2.19
# 996    1.50
# 997    3.17
# 998    1.94
# 999    2.38
# Name: fy_gpa, Length: 1000, dtype: float64

# %%
model.predict(x)
# Out:
# 0      3.032876
# 1      2.913547
# 2      2.770353
# 3      2.269172
# 4      2.555561
#          ...
# 995    2.388501
# 996    2.579427
# 997    2.722621
# 998    2.865816
# 999    2.221441
# Length: 1000, dtype: float64
